# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Assessment 1 - Atliqo dataset.csv')
df.head(120)
# Out:
#          Date Month        Gen  City code        City Company  \
# 0    1-Jan-22   Jan  Before 5G     400001     Lucknow  Atliqo
# 1    1-Jan-22   Jan  Before 5G     110001       Delhi  Atliqo
# 2    1-Jan-22   Jan  Before 5G     700001      Raipur  Atliqo
# 3    1-Jan-22   Jan  Before 5G     560001     Lucknow  Atliqo
# 4    1-Jan-22   Jan  Before 5G     600001     Lucknow  Atliqo
# ..        ...   ...        ...        ...         ...     ...
# 115  1-Sep-22   Sep   After 5G     800008      Raipur  Atliqo
# 116  1-Sep-22   Sep   After 5G     641001  Coimbatore  Atliqo
# 117  1-Sep-22   Sep   After 5G     160017       Delhi  Atliqo
# 118  1-Sep-22   Sep   After 5G     122001       Delhi  Atliqo
# 119  1-Sep-22   Sep   After 5G     492001     Lucknow  Atliqo
#
#       Revenue in crores    arpu   Active users in lakhs  \
# 0                     61     192                     32
# 1                     43     175                     24
# 2                     37     175                     21
# 3                     37     175                     21
# 4                     31     203                     15
# ..                   ...     ...                    ...
# 115                   12     250                      5
# 116                    9     177                      5
# 117                   10     163                      6
# 118                    6     238                      3
# 119                    4     173                      2
#
#      Unsubscribed users in lakhs  Time Period
# 0                              2            1
# 1                              1            1
# 2                              1            1
# 3                              1            1
# 4                              1            1
# ..                           ...          ...
# 115                            0            4
# 116                            1            4
# 117                            1            4
# 118                            0            4
# 119                            0            4
#
# [120 rows x 11 columns]

# %% [markdown]
# # Data Description

# %%
shape=df.shape
print(shape)
# Out:
# (120, 11)

# %%
size=df.size
print(size)
# Out:
# 1320

# %% [markdown]
# # Data Cleaning

# %%
print(df.isnull())
# Out:
#       Date  Month    Gen  City code   City  Company   Revenue in crores   \
# 0    False  False  False      False  False    False                False
# 1    False  False  False      False  False    False                False
# 2    False  False  False      False  False    False                False
# 3    False  False  False      False  False    False                False
# 4    False  False  False      False  False    False                False
# ..     ...    ...    ...        ...    ...      ...                  ...
# 115  False  False  False      False  False    False                False
# 116  False  False  False      False  False    False                False
# 117  False  False  False      False  False    False                False
# 118  False  False  False      False  False    False                False
# 119  False  False  False      False  False    False                False
#
#       arpu   Active users in lakhs  Unsubscribed users in lakhs  Time Period
# 0     False                  False                        False        False
# 1     False                  False                        False        False
# 2     False                  False                        False        False
# 3     False                  False                        False        False
# 4     False                  False                        False        False
# ..      ...                    ...                          ...          ...
# 115   False                  False                        False        False
# 116   False                  False                        False        False
# 117   False                  False                        False        False
# 118   False                  False                        False        False
# 119   False                  False                        False        False
#
# [120 rows x 11 columns]

# %%
print(df.isnull().sum())
# Out:
# Date                           0
# Month                          0
# Gen                            0
# City code                      0
# City                           0
# Company                        0
#  Revenue in crores             0
#  arpu                          0
# Active users in lakhs          0
# Unsubscribed users in lakhs    0
# Time Period                    0
# dtype: int64

# %% [markdown]
# # Data Visualization Techniques

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Revenue

# %% [markdown]
# ### Revenue before and after 5G

# %%
x=df['Month']
# Jan-April(Before 5G)
#Jun-Sept(After 5G)
y=(61, 43, 37, 37, 31, 28, 24, 21, 22, 12, 15, 8, 6, 5, 4, 61, 54, 39, 47, 56, 34, 29, 21, 16, 25, 12, 12, 6, 9, 4, 57, 49, 67, 42, 31, 28, 31, 29, 17, 15, 11, 17, 8, 6, 3, 65, 51, 49, 42, 33, 28, 46, 24, 15, 13, 12, 9, 10, 6, 4, 62, 42, 37, 38, 31, 28, 25, 21, 23, 12, 15, 8, 6, 6, 4, 60, 51, 38, 46, 54, 33, 28, 19, 15, 25, 11, 12, 6, 9, 4, 58, 49, 69, 44, 30, 28, 32, 29, 18, 16, 11, 18, 8, 6, 4, 65, 48, 48, 42, 32, 27, 46, 23, 15, 13, 12, 9, 10, 6, 4)

plt.title('Revenue before and after 5G')
plt.xlabel('Month')
plt.ylabel('Revenue/crores')

plt.plot(x,y,color='Blue')

# %% [markdown]
# ### City with highest revenue

# %%
x=df['City']
y=[61, 43, 37, 37, 31, 28, 24, 21, 22, 12, 15, 8, 6, 5, 4, 61, 54, 39, 47, 56, 34, 29, 21, 16, 25, 12, 12, 6, 9, 4, 57, 49, 67, 42, 31, 28, 31, 29, 17, 15, 11, 17, 8, 6, 3, 65, 51, 49, 42, 33, 28, 46, 24, 15, 13, 12, 9, 10, 6, 4, 
62, 42, 37, 38, 31, 28, 25, 21, 23, 12, 15, 8, 6, 6, 4, 60, 51, 38, 46, 54, 33, 28, 19, 15, 25, 11, 12, 6, 9, 4, 58, 49, 69, 44, 30, 28, 32, 29, 18, 16, 11, 18, 8, 6, 4, 65, 48, 48, 42, 32, 27, 46, 23, 15, 13, 12, 9, 10, 6, 4]

plt.scatter(x,y,label='City with Highest Revenue Before and After 5G')
plt.xlabel('City')
plt.ylabel('Revenue / crores')
plt.legend()

# %% [markdown]
# ## Average Revenue Per User (ARPU)

# %% [markdown]
# ### ARPU Before and After 5G

# %%
y= 192, 175, 175, 175, 203, 183, 200, 165, 189, 198, 188, 212, 185, 181, 191, 169, 189, 175, 189, 206, 193, 190, 171, 199, 210, 208, 170, 162, 187, 168, 213, 171, 187, 166, 211, 211, 201, 206, 186, 212, 197, 206, 202, 181, 197, 213, 191, 198, 169, 192, 199, 209, 163, 206, 193, 177, 212, 181, 185, 181, 193, 198, 199, 242, 198, 224, 199, 205, 251, 219, 252, 236, 199, 197, 255, 243, 240, 169, 186, 196, 164, 173, 175, 182, 162, 212, 218, 250, 231, 236, 248, 202, 195, 183, 209, 231, 161, 224, 175, 248, 212, 235, 191, 192, 237, 240, 218, 209, 225, 188, 250, 164, 255, 229, 249, 250, 177, 163, 238, 173
x=df['Gen']

plt.barh(x,y,label='ARPU Before and After Sales',color='yellowgreen')
plt.xlabel('ARPU')
plt.ylabel('Gen')
# Out:
# Text(0, 0.5, 'Gen')

# %% [markdown]
# ## Active Users

# %% [markdown]
# ### Active users before and after 5G

# %%
x_values=df['Month']
# Jan-April(Before 5G)
#Jun-Sept(After 5G)
y_values=df['Active users in lakhs']

plt.bar(x_values,y_values,label='Number 0f Active Users Before and After 5G',color='b')

plt.ylabel('Active users')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# ### City with highest number of active users

# %%
x=df['City']
y=df['Active users in lakhs']

plt.barh(x,y,label='City with Highest Number of Active Users',color='yellowgreen')
plt.ylabel('City')
plt.xlabel('Active users / Lakhs')
# Out:
# Text(0.5, 0, 'Active users / Lakhs')

# %% [markdown]
# ## Unsubscribers (Churn Rate)

# %% [markdown]
# ### Number of unsubscribers per city

# %%
a=df["City"].value_counts().head(10)
print(a)
plt.figure(figsize=(8,8))
cols_values = ['orange','cyan','grey','indigo','green']
plt.pie(a,labels=df["City"].value_counts().head(10).index,autopct="%0.0f%%",shadow=True,explode=[0.2,0.1,0,0,0,],startangle=90,colors=cols_values);
plt.show()
# Out:
# Lucknow       48
# Delhi         40
# Raipur        16
# Ahmedabad      8
# Coimbatore     8
# Name: City, dtype: int64

# %% [markdown]
# ### Number of Unsubscribers Before and After 5G

# %%
x=df['Gen']
y=df['Unsubscribed users in lakhs']


plt.xlabel('Gen')
plt.ylabel('Unsubscribers / Lakhs')

plt.bar(x,y,label='Unsubscribers Before and After 5G',color='b')


plt.plot(x,y,color='Blue')

# %% [markdown]
# ## Geographical Visualization

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Polygon,Point
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

sns.set_style('whitegrid')

# %%
import shapefile as shp

# %%
fp = r'E:\India map'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
map_df.head()
# Out:
#    id                        st_nm  \
# 0 NaN  Andaman and Nicobar Islands
# 1 NaN            Arunachal Pradesh
# 2 NaN                        Assam
# 3 NaN                        Bihar
# 4 NaN                   Chandigarh
#
#                                             geometry
# 0  MULTIPOLYGON (((93.84831 7.24028, 93.92705 7.0...
# 1  POLYGON ((95.23643 26.68105, 95.19594 27.03612...
# 2  POLYGON ((95.19594 27.03612, 95.08795 26.94578...
# 3  POLYGON ((88.11357 26.54028, 88.28006 26.37640...
# 4  POLYGON ((76.84208 30.76124, 76.83758 30.72552...

# %%
map_df.plot()

# %%
data=pd.read_csv('India Cities.csv')

# %%
data_1=data.join(map_df)

# %%
Atliqo=pd.read_csv('AtliQo_data.csv')

# %%
new_data=data_1.join(Atliqo)
new_data.head()
# Out:
#         city      lat      lng  id                        st_nm  \
# 0      Delhi  28.6600  77.2300 NaN  Andaman and Nicobar Islands
# 1     Mumbai  18.9667  72.8333 NaN            Arunachal Pradesh
# 2    Kolkāta  22.5411  88.3378 NaN                        Assam
# 3  Bangalore  12.9699  77.5980 NaN                        Bihar
# 4    Chennai  13.0825  80.2750 NaN                   Chandigarh
#
#                                             geometry  City code     City  \
# 0  MULTIPOLYGON (((93.84831 7.24028, 93.92705 7.0...   400001.0  Lucknow
# 1  POLYGON ((95.23643 26.68105, 95.19594 27.03612...   110001.0    Delhi
# 2  POLYGON ((95.19594 27.03612, 95.08795 26.94578...   700001.0   Raipur
# 3  POLYGON ((88.11357 26.54028, 88.28006 26.37640...   560001.0  Lucknow
# 4  POLYGON ((76.84208 30.76124, 76.83758 30.72552...   600001.0  Lucknow
#
#   Company  Active users in lakhs  Unsubscribed users in lakhs
# 0  Atliqo                   32.0                          2.0
# 1  Atliqo                   24.0                          1.0
# 2  Atliqo                   21.0                          1.0
# 3  Atliqo                   21.0                          1.0
# 4  Atliqo                   15.0                          1.0

# %%
geometry = [Point(xy) for xy in zip(new_data.lat,new_data.lng)]
fig,ax = plt.subplots(figsize =(50,50),)

ax.axis('off')
ax.set_title('Map of India showing India States', fontdict={'fontsize': '30', 'fontweight' : '20'})

map_df.boundary.plot(ax = ax)

geo_df = gpd.GeoDataFrame(geometry = [])

g = geo_df.plot(ax = ax,label = 'States',cmap='hsv',legend=True)
                
for i in range(len(new_data)):
    plt.text(new_data.lng[i],new_data.lat[i],"{}".format(new_data.city[i]),size=20)
    
plt.show()
# Out:
# C:\Users\TOSHIBA\anaconda3\lib\site-packages\geopandas\plotting.py:693: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(

# %%
data_2=pd.read_csv('Atliqo_cities.csv')
data_2.head()
# Out:
#   Atliqo_city      lat      lng
# 0       Delhi  28.6600  77.2300
# 1     Lucknow  26.8470  80.9470
# 2  Coimbatore  11.0000  76.9667
# 3   Ahmadābād  23.0300  72.5800
# 4      Raipur  21.2379  81.6337

# %%
New_data=new_data.merge(data_2)
New_data.head()
# Out:
#          city      lat      lng  id                        st_nm  \
# 0       Delhi  28.6600  77.2300 NaN  Andaman and Nicobar Islands
# 1   Ahmadābād  23.0300  72.5800 NaN                Daman and Diu
# 2     Lucknow  26.8470  80.9470 NaN                      Gujarat
# 3      Raipur  21.2379  81.6337 NaN                          NaN
# 4  Coimbatore  11.0000  76.9667 NaN                          NaN
#
#                                             geometry  City code       City  \
# 0  MULTIPOLYGON (((93.84831 7.24028, 93.92705 7.0...   400001.0    Lucknow
# 1  POLYGON ((72.80144 20.37378, 72.84418 20.47463...   380001.0  Ahmedabad
# 2  MULTIPOLYGON (((68.35808 23.80475, 68.41658 23...   226001.0      Delhi
# 3                                               None   700001.0     Raipur
# 4                                               None   411001.0    Lucknow
#
#   Company  Active users in lakhs  Unsubscribed users in lakhs Atliqo_city
# 0  Atliqo                   32.0                          2.0       Delhi
# 1  Atliqo                   13.0                          1.0   Ahmadābād
# 2  Atliqo                    6.0                          0.0     Lucknow
# 3  Atliqo                   25.0                          2.0      Raipur
# 4  Atliqo                   22.0                          1.0  Coimbatore

# %%
geometry = [Point(xy) for xy in zip(New_data.lng,New_data.lat)]
fig,ax = plt.subplots(figsize = (9,9))
ax.axis('off')
ax.set_title('Map of India showing where Atliqo is Present', fontdict={'fontsize': '20', 'fontweight' : '10'})

map_df.boundary.plot(ax = ax)

geo_df = gpd.GeoDataFrame(geometry = geometry)

g = geo_df.plot(ax = ax, markersize = 50, color = 'red',marker = '*',label = 'Cities')
                
for i in range(len(New_data)):
    plt.text(New_data.lng[i],New_data.lat[i],"{}".format(New_data.city[i]),size=10)
    
plt.show()
